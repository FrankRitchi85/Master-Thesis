# %%
# Set seeds
from numpy.random import seed
import tensorflow as tf
seed(42)
tf.random.set_seed(42)

# %%
# Upgrade module imbalanced-learn to run on Google Colab
#!pip install imbalanced-learn --upgrade

# Import modules
import imblearn
import keras
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pickle
import sklearn

from google.colab import drive
from imblearn.over_sampling import RandomOverSampler
from keras.applications.resnet import ResNet50
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, History
from keras.layers import Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.metrics import categorical_accuracy
from keras.models import Sequential,Model,load_model
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from platform import python_version
from sklearn.model_selection import train_test_split

# %matplotlib inline

# Versions
print("Version Python:",python_version())
print()
print("Version Imbalanced-learn:",imblearn.__version__)
print("Version Keras:",keras.__version__)
print("Version Matplotlib:",matplotlib.__version__)
print("Version NumPy:",np.__version__)
print("Version Pandas:",pd.__version__)
print("Version Scikit-learn:",sklearn.__version__)
print("Version TensorFlow:",tf.__version__)

# %%
# Set data folder and load dataframe
drive.mount('/content/drive')
data_folder = '/content/drive/MyDrive/'
data = pd.read_pickle(os.path.join(data_folder, 'data.pkl'))
data = data[data["sex"] == 'female']

# %%
# Setting data augmentation parameters 
data_augmentation = ImageDataGenerator(
    rotation_range = 60,
    zoom_range = 0.2,  
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    horizontal_flip = True,  
    vertical_flip = True,  
    shear_range = 10)

# %%
# Create training, validation amd test sets (Derived from: https://www.kaggle.com/kaimingk/skin-cancer-mnist-ham10000)

# Split 70%, 10%, 20%. Test and validation, together 30%, should be from unique ID's only
size_val_test = 0.3 * len(data)
val_test_ratio_from_unique = size_val_test/len(data[data.unique == True])

# Training data = remainder of unique ID's + non-uniques. Split is stratified by lesion type (benign/malignant)
bb_data_train_unique, bb_data_val_test = train_test_split(data[data["unique"] == True], test_size = val_test_ratio_from_unique, stratify=data[data["unique"] == True]["lesion_type_cat"], random_state = 42)
bb_data_train = pd.concat((bb_data_train_unique, data[data["unique"] == False]), axis = 0)

# Split validation and test sets. Split is stratified by lesion type (benign/malignant)
bb_data_validation, bb_data_test = train_test_split(bb_data_val_test, test_size = 0.6667, stratify=bb_data_val_test["lesion_type_cat"], random_state = 42)

# Class balancing (random oversampling)
X = bb_data_train.drop(['lesion_type_cat'], axis=1)
y = bb_data_train['lesion_type_cat']

X_test = bb_data_test.drop(['lesion_type_cat'], axis=1)
y_test = bb_data_test['lesion_type_cat']

ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(X, y)

ros = RandomOverSampler(random_state=42)
X_test_resampled, y_test_resampled = ros.fit_resample(X_test, y_test)

bb_data_train = pd.concat([X_resampled, y_resampled], axis=1)
bb_data_test = pd.concat([X_test_resampled, y_test_resampled], axis=1)

# Create variables for feature (x) and target (y) training, validation and test sets
bb_data_train_x = np.asarray(bb_data_train['image'].tolist())
bb_data_validation_x = np.asarray(bb_data_validation['image'].tolist())
bb_data_test_x = np.asarray(bb_data_test['image'].tolist())

bb_data_train_y = np.asarray(bb_data_train['lesion_type_cat'].tolist())
bb_data_validation_y = np.asarray(bb_data_validation['lesion_type_cat'].tolist())
bb_data_test_y = np.asarray(bb_data_test['lesion_type_cat'].tolist())

# One-hot encoding of target variable
bb_num_classes = len(np.sort(data['lesion_type_cat'].unique()))

bb_data_train_y = to_categorical(bb_data_train_y, num_classes = bb_num_classes)
bb_data_validation_y = to_categorical(bb_data_validation_y, num_classes = bb_num_classes)
bb_data_test_y = to_categorical(bb_data_test_y, num_classes = bb_num_classes)

# %%
# Fit data augmentation
data_augmentation.fit(bb_data_train_x)

# %%
# Creating ResNet model (Derived from: https://www.kaggle.com/jnegrini/ham10000-analysis-and-model-comparison)

# Model parameters
input_shape = (75, 100, 3)
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
epochs = 50
batch_size = 32

# Callbacks
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=5, verbose=1, factor=0.5, min_lr=0.00001)
early_stopping_monitor = EarlyStopping(patience=20,monitor='val_accuracy')
history = History()

# Define model architecture
base_model = ResNet50(include_top=False, input_shape=(75,100, 3),pooling = 'avg', weights = 'imagenet');

ResNet50model_binary = Sequential()
ResNet50model_binary.add(base_model)
ResNet50model_binary.add(Dropout(0.2))
ResNet50model_binary.add(Dense(128, activation="relu"))
ResNet50model_binary.add(Dropout(0.2))
ResNet50model_binary.add(Dense(bb_num_classes, activation = 'softmax'))
ResNet50model_binary.summary()

# Layers in ResNet are pretrained (ImageNet)
for layer in base_model.layers:
    layer.trainable = False

# Compile model
ResNet50model_binary.compile(optimizer = optimizer , loss = "categorical_crossentropy", metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               262272
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 23,850,242
# Trainable params: 23,797,122
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
# Fit and save model 
bb_history = ResNet50model_binary.fit(data_augmentation.flow(bb_data_train_x,bb_data_train_y, batch_size=batch_size),
                        epochs = epochs, validation_data = (bb_data_validation_x,bb_data_validation_y),
                        verbose = 1, steps_per_epoch=bb_data_train_x.shape[0] // batch_size, 
                        callbacks=[learning_rate_reduction,early_stopping_monitor, history])

ResNet50model_binary.save(os.path.join(data_folder,"Sex_Female_binary_model"))
# Out:
# Epoch 1/50
# 156/156 [==============================] - 70s 103ms/step - loss: 0.7148 - accuracy: 0.6578 - val_loss: 0.2796 - val_accuracy: 0.8584
# Epoch 2/50
# 156/156 [==============================] - 11s 70ms/step - loss: 0.5192 - accuracy: 0.7282 - val_loss: 0.2805 - val_accuracy: 0.8494
# Epoch 3/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.4999 - accuracy: 0.7392 - val_loss: 0.2404 - val_accuracy: 0.8831
# Epoch 4/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.4946 - accuracy: 0.7485 - val_loss: 0.2626 - val_accuracy: 0.8539
# Epoch 5/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.4797 - accuracy: 0.7573 - val_loss: 0.2798 - val_accuracy: 0.8427
# Epoch 6/50
# 156/156 [==============================] - 11s 70ms/step - loss: 0.4776 - accuracy: 0.7496 - val_loss: 0.2576 - val_accuracy: 0.8494
# Epoch 7/50
# 156/156 [==============================] - 11s 70ms/step - loss: 0.4706 - accuracy: 0.7629 - val_loss: 0.2091 - val_accuracy: 0.8809
# Epoch 8/50
# 156/156 [==============================] - 11s 72ms/step - loss: 0.4530 - accuracy: 0.7733 - val_loss: 0.2286 - val_accuracy: 0.8674
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 9/50
# 156/156 [==============================] - 11s 72ms/step - loss: 0.4530 - accuracy: 0.7733 - val_loss: 0.2243 - val_accuracy: 0.8652
# Epoch 10/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.4453 - accuracy: 0.7698 - val_loss: 0.2088 - val_accuracy: 0.8764
# Epoch 11/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.4373 - accuracy: 0.7790 - val_loss: 0.2066 - val_accuracy: 0.8787
# Epoch 12/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.4339 - accuracy: 0.7884 - val_loss: 0.2829 - val_accuracy: 0.8494
# Epoch 13/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.4236 - accuracy: 0.7966 - val_loss: 0.1921 - val_accuracy: 0.8966
# Epoch 14/50
# 156/156 [==============================] - 11s 70ms/step - loss: 0.4201 - accuracy: 0.7951 - val_loss: 0.2103 - val_accuracy: 0.8854
# Epoch 15/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.4265 - accuracy: 0.7779 - val_loss: 0.2099 - val_accuracy: 0.8764
# Epoch 16/50
# 156/156 [==============================] - 11s 71ms/step - loss: 0.4129 - accuracy: 0.8013 - val_loss: 0.2090 - val_accuracy: 0.8764
# Epoch 17/50
# 156/156 [==============================] - 11s 71ms/step - loss: 0.4067 - accuracy: 0.8058 - val_loss: 0.2453 - val_accuracy: 0.8674
# Epoch 18/50
# 156/156 [==============================] - 11s 70ms/step - loss: 0.4017 - accuracy: 0.8067 - val_loss: 0.2159 - val_accuracy: 0.8876
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 19/50
# 156/156 [==============================] - 11s 70ms/step - loss: 0.4123 - accuracy: 0.8010 - val_loss: 0.2053 - val_accuracy: 0.8854
# Epoch 20/50
# 156/156 [==============================] - 11s 70ms/step - loss: 0.4003 - accuracy: 0.8038 - val_loss: 0.2138 - val_accuracy: 0.8809
# Epoch 21/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.4096 - accuracy: 0.7952 - val_loss: 0.2342 - val_accuracy: 0.8764
# Epoch 22/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.3998 - accuracy: 0.8070 - val_loss: 0.2078 - val_accuracy: 0.8876
# Epoch 23/50
# 156/156 [==============================] - 11s 71ms/step - loss: 0.3952 - accuracy: 0.8153 - val_loss: 0.2176 - val_accuracy: 0.8809
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 24/50
# 156/156 [==============================] - 11s 72ms/step - loss: 0.4061 - accuracy: 0.7967 - val_loss: 0.2113 - val_accuracy: 0.8854
# Epoch 25/50
# 156/156 [==============================] - 11s 72ms/step - loss: 0.3781 - accuracy: 0.8224 - val_loss: 0.2136 - val_accuracy: 0.8876
# Epoch 26/50
# 156/156 [==============================] - 11s 71ms/step - loss: 0.3758 - accuracy: 0.8170 - val_loss: 0.2039 - val_accuracy: 0.8944
# Epoch 27/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.3790 - accuracy: 0.8147 - val_loss: 0.2089 - val_accuracy: 0.8944
# Epoch 28/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.3983 - accuracy: 0.8148 - val_loss: 0.2059 - val_accuracy: 0.8831
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 29/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.3720 - accuracy: 0.8187 - val_loss: 0.2026 - val_accuracy: 0.8921
# Epoch 30/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.3898 - accuracy: 0.8124 - val_loss: 0.2018 - val_accuracy: 0.8876
# Epoch 31/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.3813 - accuracy: 0.8264 - val_loss: 0.2021 - val_accuracy: 0.8921
# Epoch 32/50
# 156/156 [==============================] - 11s 72ms/step - loss: 0.3864 - accuracy: 0.8111 - val_loss: 0.2041 - val_accuracy: 0.8921
# Epoch 33/50
# 156/156 [==============================] - 11s 72ms/step - loss: 0.3852 - accuracy: 0.8183 - val_loss: 0.1918 - val_accuracy: 0.8989
# Epoch 34/50
# 156/156 [==============================] - 11s 70ms/step - loss: 0.3867 - accuracy: 0.8168 - val_loss: 0.1927 - val_accuracy: 0.9034
# Epoch 35/50
# 156/156 [==============================] - 11s 70ms/step - loss: 0.3778 - accuracy: 0.8219 - val_loss: 0.2039 - val_accuracy: 0.8899
# Epoch 36/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.3879 - accuracy: 0.8117 - val_loss: 0.2033 - val_accuracy: 0.8921
# Epoch 37/50
# 156/156 [==============================] - 11s 70ms/step - loss: 0.3853 - accuracy: 0.8180 - val_loss: 0.2031 - val_accuracy: 0.8966
# Epoch 38/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.3962 - accuracy: 0.8099 - val_loss: 0.2025 - val_accuracy: 0.8921
# Epoch 39/50
# 156/156 [==============================] - 11s 70ms/step - loss: 0.3782 - accuracy: 0.8197 - val_loss: 0.2019 - val_accuracy: 0.8944
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 40/50
# 156/156 [==============================] - 11s 68ms/step - loss: 0.3794 - accuracy: 0.8194 - val_loss: 0.1995 - val_accuracy: 0.8966
# Epoch 41/50
# 156/156 [==============================] - 11s 70ms/step - loss: 0.3870 - accuracy: 0.8130 - val_loss: 0.2036 - val_accuracy: 0.8944
# Epoch 42/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.3990 - accuracy: 0.8072 - val_loss: 0.1996 - val_accuracy: 0.8944
# Epoch 43/50
# 156/156 [==============================] - 11s 68ms/step - loss: 0.3810 - accuracy: 0.8207 - val_loss: 0.2014 - val_accuracy: 0.8899
# Epoch 44/50
# 156/156 [==============================] - 11s 70ms/step - loss: 0.3750 - accuracy: 0.8249 - val_loss: 0.1965 - val_accuracy: 0.9011
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 45/50
# 156/156 [==============================] - 11s 68ms/step - loss: 0.3756 - accuracy: 0.8154 - val_loss: 0.1991 - val_accuracy: 0.8989
# Epoch 46/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.3812 - accuracy: 0.8221 - val_loss: 0.1998 - val_accuracy: 0.8944
# Epoch 47/50
# 156/156 [==============================] - 11s 69ms/step - loss: 0.3910 - accuracy: 0.8173 - val_loss: 0.2017 - val_accuracy: 0.8921
# Epoch 48/50
# 156/156 [==============================] - 11s 68ms/step - loss: 0.3735 - accuracy: 0.8278 - val_loss: 0.2001 - val_accuracy: 0.8944
# Epoch 49/50
# 156/156 [==============================] - 11s 70ms/step - loss: 0.3919 - accuracy: 0.8084 - val_loss: 0.2009 - val_accuracy: 0.8899
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 50/50
# 156/156 [==============================] - 11s 68ms/step - loss: 0.3644 - accuracy: 0.8238 - val_loss: 0.2007 - val_accuracy: 0.8921
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Sex_Female_binary_model/assets

# %%
# Accuracy over epochs
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Loss - Sex_Female (binary)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
filename = str('Model Accuracy - Sex_Female (binary).png')
plt.savefig(os.path.join(data_folder,filename), dpi=600)
plt.show()

# Loss over epochs
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss - Sex_Female (binary)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
filename = str('Model Loss - Sex_Female (binary).png')
plt.savefig(os.path.join(data_folder,filename), dpi=600)
plt.show()

# %%
with open(os.path.join(data_folder, 'data_bb_sex_female.pkl'), 'wb') as f:
    pickle.dump([bb_data_train_x,bb_data_validation_x,bb_data_test_x,bb_data_train_y,bb_data_validation_y,bb_data_test_y], f)
