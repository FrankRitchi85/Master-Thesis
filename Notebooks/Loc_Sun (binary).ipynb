# %%
# Set seeds
from numpy.random import seed
import tensorflow as tf
seed(42)
tf.random.set_seed(42)

# %%
# Upgrade module imbalanced-learn to run on Google Colab
#!pip install imbalanced-learn --upgrade

# Import modules
import imblearn
import keras
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pickle
import sklearn

from google.colab import drive
from imblearn.over_sampling import RandomOverSampler
from keras.applications.resnet import ResNet50
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, History
from keras.layers import Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.metrics import categorical_accuracy
from keras.models import Sequential,Model,load_model
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from platform import python_version
from sklearn.model_selection import train_test_split

# %matplotlib inline

# Versions
print("Version Python:",python_version())
print()
print("Version Imbalanced-learn:",imblearn.__version__)
print("Version Keras:",keras.__version__)
print("Version Matplotlib:",matplotlib.__version__)
print("Version NumPy:",np.__version__)
print("Version Pandas:",pd.__version__)
print("Version Scikit-learn:",sklearn.__version__)
print("Version TensorFlow:",tf.__version__)

# %%
# Set data folder and load dataframe
drive.mount('/content/drive')
data_folder = '/content/drive/MyDrive/'
data = pd.read_pickle(os.path.join(data_folder, 'data.pkl'))
data = data[data["loc_group"] == 'Sun']

# %%
# Setting data augmentation parameters 
data_augmentation = ImageDataGenerator(
    rotation_range = 60,
    zoom_range = 0.2,  
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    horizontal_flip = True,  
    vertical_flip = True,  
    shear_range = 10)

# %%
# Create training, validation amd test sets (Derived from: https://www.kaggle.com/kaimingk/skin-cancer-mnist-ham10000)

# Split 70%, 10%, 20%. Test and validation, together 30%, should be from unique ID's only
size_val_test = 0.3 * len(data)
val_test_ratio_from_unique = size_val_test/len(data[data.unique == True])

# Training data = remainder of unique ID's + non-uniques. Split is stratified by lesion type (benign/malignant)
bb_data_train_unique, bb_data_val_test = train_test_split(data[data["unique"] == True], test_size = val_test_ratio_from_unique, stratify=data[data["unique"] == True]["lesion_type_cat"], random_state = 42)
bb_data_train = pd.concat((bb_data_train_unique, data[data["unique"] == False]), axis = 0)

# Split validation and test sets. Split is stratified by lesion type (benign/malignant)
bb_data_validation, bb_data_test = train_test_split(bb_data_val_test, test_size = 0.6667, stratify=bb_data_val_test["lesion_type_cat"], random_state = 42)

# Class balancing (random oversampling)
X = bb_data_train.drop(['lesion_type_cat'], axis=1)
y = bb_data_train['lesion_type_cat']

X_test = bb_data_test.drop(['lesion_type_cat'], axis=1)
y_test = bb_data_test['lesion_type_cat']

ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(X, y)

ros = RandomOverSampler(random_state=42)
X_test_resampled, y_test_resampled = ros.fit_resample(X_test, y_test)

bb_data_train = pd.concat([X_resampled, y_resampled], axis=1)
bb_data_test = pd.concat([X_test_resampled, y_test_resampled], axis=1)

# Create variables for feature (x) and target (y) training, validation and test sets
bb_data_train_x = np.asarray(bb_data_train['image'].tolist())
bb_data_validation_x = np.asarray(bb_data_validation['image'].tolist())
bb_data_test_x = np.asarray(bb_data_test['image'].tolist())

bb_data_train_y = np.asarray(bb_data_train['lesion_type_cat'].tolist())
bb_data_validation_y = np.asarray(bb_data_validation['lesion_type_cat'].tolist())
bb_data_test_y = np.asarray(bb_data_test['lesion_type_cat'].tolist())

# One-hot encoding of target variable
bb_num_classes = len(np.sort(data['lesion_type_cat'].unique()))

bb_data_train_y = to_categorical(bb_data_train_y, num_classes = bb_num_classes)
bb_data_validation_y = to_categorical(bb_data_validation_y, num_classes = bb_num_classes)
bb_data_test_y = to_categorical(bb_data_test_y, num_classes = bb_num_classes)

# %%
# Fit data augmentation
data_augmentation.fit(bb_data_train_x)

# %%
# Creating ResNet model (Derived from: https://www.kaggle.com/jnegrini/ham10000-analysis-and-model-comparison)

# Model parameters
input_shape = (75, 100, 3)
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
epochs = 50
batch_size = 32

# Callbacks
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=5, verbose=1, factor=0.5, min_lr=0.00001)
early_stopping_monitor = EarlyStopping(patience=20,monitor='val_accuracy')
history = History()

# Define model architecture
base_model = ResNet50(include_top=False, input_shape=(75,100, 3),pooling = 'avg', weights = 'imagenet');

ResNet50model_binary = Sequential()
ResNet50model_binary.add(base_model)
ResNet50model_binary.add(Dropout(0.2))
ResNet50model_binary.add(Dense(128, activation="relu"))
ResNet50model_binary.add(Dropout(0.2))
ResNet50model_binary.add(Dense(bb_num_classes, activation = 'softmax'))
ResNet50model_binary.summary()

# Layers in ResNet are pretrained (ImageNet)
for layer in base_model.layers:
    layer.trainable = False

# Compile model
ResNet50model_binary.compile(optimizer = optimizer , loss = "categorical_crossentropy", metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               262272
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 23,850,242
# Trainable params: 23,797,122
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
# Fit and save model 
bb_history = ResNet50model_binary.fit(data_augmentation.flow(bb_data_train_x,bb_data_train_y, batch_size=batch_size),
                        epochs = epochs, validation_data = (bb_data_validation_x,bb_data_validation_y),
                        verbose = 1, steps_per_epoch=bb_data_train_x.shape[0] // batch_size, 
                        callbacks=[learning_rate_reduction,early_stopping_monitor, history])

ResNet50model_binary.save(os.path.join(data_folder,"Loc_Sun_binary_model"))
# Out:
# Epoch 1/50
# 135/135 [==============================] - 67s 103ms/step - loss: 0.7325 - accuracy: 0.6527 - val_loss: 0.2939 - val_accuracy: 0.8513
# Epoch 2/50
# 135/135 [==============================] - 9s 70ms/step - loss: 0.5667 - accuracy: 0.7060 - val_loss: 0.2620 - val_accuracy: 0.8650
# Epoch 3/50
# 135/135 [==============================] - 10s 70ms/step - loss: 0.5141 - accuracy: 0.7307 - val_loss: 0.2801 - val_accuracy: 0.8604
# Epoch 4/50
# 135/135 [==============================] - 9s 69ms/step - loss: 0.5271 - accuracy: 0.7234 - val_loss: 0.2527 - val_accuracy: 0.8673
# Epoch 5/50
# 135/135 [==============================] - 9s 68ms/step - loss: 0.5128 - accuracy: 0.7438 - val_loss: 0.2797 - val_accuracy: 0.8444
# Epoch 6/50
# 135/135 [==============================] - 9s 68ms/step - loss: 0.4946 - accuracy: 0.7440 - val_loss: 0.2688 - val_accuracy: 0.8627
# Epoch 7/50
# 135/135 [==============================] - 9s 69ms/step - loss: 0.4937 - accuracy: 0.7478 - val_loss: 0.3173 - val_accuracy: 0.8467
# Epoch 8/50
# 135/135 [==============================] - 9s 69ms/step - loss: 0.4714 - accuracy: 0.7669 - val_loss: 0.2468 - val_accuracy: 0.8764
# Epoch 9/50
# 135/135 [==============================] - 10s 71ms/step - loss: 0.4824 - accuracy: 0.7619 - val_loss: 0.2370 - val_accuracy: 0.8764
# Epoch 10/50
# 135/135 [==============================] - 9s 69ms/step - loss: 0.4863 - accuracy: 0.7492 - val_loss: 0.2866 - val_accuracy: 0.8535
# Epoch 11/50
# 135/135 [==============================] - 9s 68ms/step - loss: 0.4858 - accuracy: 0.7499 - val_loss: 0.2902 - val_accuracy: 0.8467
# Epoch 12/50
# 135/135 [==============================] - 9s 69ms/step - loss: 0.4837 - accuracy: 0.7520 - val_loss: 0.2358 - val_accuracy: 0.8970
# Epoch 13/50
# 135/135 [==============================] - 9s 68ms/step - loss: 0.4779 - accuracy: 0.7602 - val_loss: 0.2460 - val_accuracy: 0.8604
# Epoch 14/50
# 135/135 [==============================] - 9s 70ms/step - loss: 0.4578 - accuracy: 0.7716 - val_loss: 0.2579 - val_accuracy: 0.8787
# Epoch 15/50
# 135/135 [==============================] - 9s 69ms/step - loss: 0.4816 - accuracy: 0.7493 - val_loss: 0.2520 - val_accuracy: 0.8535
# Epoch 16/50
# 135/135 [==============================] - 9s 68ms/step - loss: 0.4590 - accuracy: 0.7652 - val_loss: 0.2371 - val_accuracy: 0.8741
# Epoch 17/50
# 135/135 [==============================] - 9s 69ms/step - loss: 0.4493 - accuracy: 0.7819 - val_loss: 0.2232 - val_accuracy: 0.8902
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 18/50
# 135/135 [==============================] - 9s 68ms/step - loss: 0.4715 - accuracy: 0.7616 - val_loss: 0.2292 - val_accuracy: 0.8924
# Epoch 19/50
# 135/135 [==============================] - 9s 67ms/step - loss: 0.4391 - accuracy: 0.7807 - val_loss: 0.2396 - val_accuracy: 0.8719
# Epoch 20/50
# 135/135 [==============================] - 9s 68ms/step - loss: 0.4198 - accuracy: 0.7952 - val_loss: 0.2564 - val_accuracy: 0.8719
# Epoch 21/50
# 135/135 [==============================] - 9s 68ms/step - loss: 0.4417 - accuracy: 0.7879 - val_loss: 0.2258 - val_accuracy: 0.8879
# Epoch 22/50
# 135/135 [==============================] - 9s 69ms/step - loss: 0.4372 - accuracy: 0.7846 - val_loss: 0.2507 - val_accuracy: 0.8741
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 23/50
# 135/135 [==============================] - 9s 68ms/step - loss: 0.4324 - accuracy: 0.7919 - val_loss: 0.2344 - val_accuracy: 0.8833
# Epoch 24/50
# 135/135 [==============================] - 9s 67ms/step - loss: 0.4381 - accuracy: 0.7822 - val_loss: 0.2445 - val_accuracy: 0.8856
# Epoch 25/50
# 135/135 [==============================] - 9s 68ms/step - loss: 0.4345 - accuracy: 0.7789 - val_loss: 0.2444 - val_accuracy: 0.8833
# Epoch 26/50
# 135/135 [==============================] - 9s 70ms/step - loss: 0.4463 - accuracy: 0.7793 - val_loss: 0.2348 - val_accuracy: 0.8787
# Epoch 27/50
# 135/135 [==============================] - 10s 72ms/step - loss: 0.4296 - accuracy: 0.7902 - val_loss: 0.2367 - val_accuracy: 0.8970
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 28/50
# 135/135 [==============================] - 9s 68ms/step - loss: 0.4511 - accuracy: 0.7739 - val_loss: 0.2418 - val_accuracy: 0.8833
# Epoch 29/50
# 135/135 [==============================] - 9s 70ms/step - loss: 0.4256 - accuracy: 0.7978 - val_loss: 0.2362 - val_accuracy: 0.8833
# Epoch 30/50
# 135/135 [==============================] - 9s 69ms/step - loss: 0.4207 - accuracy: 0.8030 - val_loss: 0.2420 - val_accuracy: 0.8764
# Epoch 31/50
# 135/135 [==============================] - 10s 70ms/step - loss: 0.4527 - accuracy: 0.7655 - val_loss: 0.2416 - val_accuracy: 0.8787
# Epoch 32/50
# 135/135 [==============================] - 9s 69ms/step - loss: 0.4225 - accuracy: 0.7919 - val_loss: 0.2371 - val_accuracy: 0.8902
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Loc_Sun_binary_model/assets

# %%
# Accuracy over epochs
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Loss - Loc_Sun (binary)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
filename = str('Model Accuracy - Loc_Sun (binary).png')
plt.savefig(os.path.join(data_folder,filename), dpi=600)
plt.show()

# Loss over epochs
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss - Loc_Sun (binary)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
filename = str('Model Loss - Loc_Sun (binary).png')
plt.savefig(os.path.join(data_folder,filename), dpi=600)
plt.show()

# %%
with open(os.path.join(data_folder, 'data_bb_loc_sun.pkl'), 'wb') as f:
    pickle.dump([bb_data_train_x,bb_data_validation_x,bb_data_test_x,bb_data_train_y,bb_data_validation_y,bb_data_test_y], f)
